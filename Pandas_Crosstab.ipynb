# %% [markdown]
# <a href="https://colab.research.google.com/github/balakumar-dataengineer/testrepo/blob/master/Pandas_Crosstab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df=pd.read_excel('/content/drive/My Drive/Colab Notebooks/Pandas/survey.xls')
df
# Out:
#       Name Nationality     Sex  Age Handedness
# 0    Kathy         USA  Female   23      Right
# 1    Linda         USA  Female   18      Right
# 2    Peter         USA    Male   19      Right
# 3     John         USA    Male   22       Left
# 4   Fatima   Bangadesh  Female   31       Left
# 5    Kadir   Bangadesh    Male   25       Left
# 6   Dhaval       India    Male   35       Left
# 7   Sudhir       India    Male   31       Left
# 8   Parvir       India    Male   37      Right
# 9      Yan       China  Female   52      Right
# 10    Juan       China  Female   58       Left
# 11   Liang       China    Male   43       Left

# %%
df.pivot_table(index='Nationality',columns='Sex',values='Age',aggfunc='min')
# Out:
# Sex          Female  Male
# Nationality
# Bangadesh      31.0  25.0
# China          52.0  43.0
# India           NaN  31.0
# USA            18.0  19.0

# %%
pd.crosstab(index=df.Nationality,columns=[df.Sex,df.Handedness],values=df.Age,aggfunc='sum',normalize='index',margins=True)
# Out:
# Sex            Female                Male
# Handedness       Left     Right      Left     Right
# Nationality
# Bangadesh    0.553571  0.000000  0.446429  0.000000
# China        0.379085  0.339869  0.281046  0.000000
# India        0.000000  0.000000  0.640777  0.359223
# USA          0.000000  0.500000  0.268293  0.231707
# All          0.225888  0.236041  0.395939  0.142132
