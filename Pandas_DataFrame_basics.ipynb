# %% [markdown]
# <a href="https://colab.research.google.com/github/balakumar-dataengineer/testrepo/blob/master/Pandas_DataFrame_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df=pd.read_csv('/content/drive/My Drive/Colab Notebooks/Testfiles/csv/csv1/balakumar.csv')

# %%
df.head()
# Out:
#         orderId orderStatus            orderTime                 restaurant  \
# 0  1.593730e+14   Delivered  2023-11-19 19:40:53             Domino's Pizza
# 1  1.593510e+14   Delivered  2023-11-19 13:45:31  A2B - Adyar Ananda Bhavan
# 2  1.563280e+14   Delivered  2023-10-15 13:51:36  A2B - Adyar Ananda Bhavan
# 3  1.557470e+14   Delivered  2023-10-08 20:28:10     Dindigul Thalappakatti
# 4  1.557210e+14   Delivered  2023-10-08 13:17:31  A2B - Adyar Ananda Bhavan
#
#    totalCost
# 0        278
# 1        227
# 2        229
# 3        187
# 4        191

# %%
df.tail()
# Out:
#          orderId orderStatus            orderTime                  restaurant  \
# 22  1.580570e+11   Delivered  2023-01-29 14:20:32  Namma Veedu Vasanta Bhavan
# 23  1.580110e+11   Delivered  2023-01-29 01:28:50                  Chai Kings
# 24  1.579740e+11   Delivered  2023-01-28 15:09:30      Dindigul Thalappakatti
# 25  1.578820e+11   Delivered  2023-01-27 13:41:00  Namma Veedu Vasanta Bhavan
# 26  1.576650e+11   Delivered  2023-01-25 01:20:34                  Chai Kings
#
#     totalCost
# 22        152
# 23        178
# 24        283
# 25        152
# 26        186

# %%
df
# Out:
#          orderId orderStatus            orderTime                  restaurant  \
# 0   1.593730e+14   Delivered  2023-11-19 19:40:53              Domino's Pizza
# 1   1.593510e+14   Delivered  2023-11-19 13:45:31   A2B - Adyar Ananda Bhavan
# 2   1.563280e+14   Delivered  2023-10-15 13:51:36   A2B - Adyar Ananda Bhavan
# 3   1.557470e+14   Delivered  2023-10-08 20:28:10      Dindigul Thalappakatti
# 4   1.557210e+14   Delivered  2023-10-08 13:17:31   A2B - Adyar Ananda Bhavan
# 5   1.556360e+14   Delivered  2023-10-07 13:47:25   A2B - Adyar Ananda Bhavan
# 6   1.730920e+11   Delivered  2023-07-22 14:36:33   A2B - Adyar Ananda Bhavan
# 7   1.725930e+11   Delivered  2023-07-16 20:07:57              Domino's Pizza
# 8   1.725720e+11   Delivered  2023-07-16 14:11:50   A2B - Adyar Ananda Bhavan
# 9   1.701740e+11   Delivered  2023-06-18 20:03:44                    Anjappar
# 10  1.689430e+11   Delivered  2023-06-04 14:07:04   A2B - Adyar Ananda Bhavan
# ...

# %%
df.orderId.head(4)
# Out:
# 0    1.593730e+14
# 1    1.593510e+14
# 2    1.563280e+14
# 3    1.557470e+14
# Name: orderId, dtype: float64

# %%
df[['orderTime','totalCost']][df['totalCost']>=1000]
# Out:
#               orderTime  totalCost
# 17  2023-02-17 12:41:04       1239

# %%
data=[
    (1,'bala',25),
    (2,'kumar',25)
]

columns=['id','name','age']

df1=pd.DataFrame(data,columns=columns)
df1
# Out:
#    id   name  age
# 0   1   bala   25
# 1   2  kumar   25

# %%
df1.describe()
# Out:
#              id   age
# count  2.000000   2.0
# mean   1.500000  25.0
# std    0.707107   0.0
# min    1.000000  25.0
# 25%    1.250000  25.0
# 50%    1.500000  25.0
# 75%    1.750000  25.0
# max    2.000000  25.0

# %%
df1.max()
# Out:
# id          2
# name    kumar
# age        25
# dtype: object

# %%
df1.columns
# Out:
# Index(['id', 'name', 'age'], dtype='object')

# %%
df1.shape
# Out:
# (2, 3)

# %%
rows,columns= df1.shape

# %%
rows
# Out:
# 2

# %%
columns
# Out:
# 3

# %%
df[::-1].head(1)
# Out:
#          orderId orderStatus            orderTime  restaurant  totalCost
# 26  1.576650e+11   Delivered  2023-01-25 01:20:34  Chai Kings        186

# %%
type(df['restaurant'])
# Out:
# pandas.core.series.Series

# %%
df.restaurant.dtype
# Out:
# dtype('O')

# %%
df.totalCost.std()
# Out:
# 212.49831237808164

# %%
df[['orderId','totalCost']][df['totalCost']==df['totalCost'].min()]
# Out:
#          orderId  totalCost
# 22  1.580570e+11        152
# 25  1.578820e+11        152

# %%
df.index
# Out:
# RangeIndex(start=0, stop=27, step=1)

# %%
df1=df.set_index('orderStatus',inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df.loc['Delivered']
# Out:
#                        orderTime                  restaurant  totalCost
# orderStatus
# Delivered    2023-11-19 19:40:53              Domino's Pizza        278
# Delivered    2023-11-19 13:45:31   A2B - Adyar Ananda Bhavan        227
# Delivered    2023-10-15 13:51:36   A2B - Adyar Ananda Bhavan        229
# Delivered    2023-10-08 20:28:10      Dindigul Thalappakatti        187
# Delivered    2023-10-08 13:17:31   A2B - Adyar Ananda Bhavan        191
# Delivered    2023-10-07 13:47:25   A2B - Adyar Ananda Bhavan        256
# Delivered    2023-07-22 14:36:33   A2B - Adyar Ananda Bhavan        180
# Delivered    2023-07-16 20:07:57              Domino's Pizza        578
# Delivered    2023-07-16 14:11:50   A2B - Adyar Ananda Bhavan        361
# Delivered    2023-06-18 20:03:44                    Anjappar        218
# Delivered    2023-06-04 14:07:04   A2B - Adyar Ananda Bhavan        250
# Delivered    2023-06-03 15:37:22              Domino's Pizza        208
# ...
