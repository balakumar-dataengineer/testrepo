# %% [markdown]
# <a href="https://colab.research.google.com/github/balakumar-dataengineer/testrepo/blob/master/Pandas_Different_ways_to_create_a_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df=pd.read_csv('/content/drive/My Drive/Colab Notebooks/Testfiles/csv/csv1/balakumar-2.csv')

df.orderId.count()
# Out:
# np.int64(27)

# %%
df=pd.read_excel('/content/drive/My Drive/Colab Notebooks/Testfiles/csv/csv1/tracks.xlsx','tracks')
df.count()
# Out:
# id                  586672
# name                586592
# popularity          586672
# duration_ms         586672
# explicit            586672
# artists             586672
# id_artists          586672
# release_date        586672
# danceability        586672
# energy              586672
# key                 586672
# loudness            586672
# mode                586672
# speechiness         586672
# acousticness        586672
# instrumentalness    586672
# liveness            586672
# valence             586672
# tempo               586672
# time_signature      586672
# dtype: int64

# %%
data={
    "name":['bala','kumar','balakumar',None],
    "age":[25,26,27,None],
    "salary":[150000,175000,200000,300000]
}

df=pd.DataFrame(data)
df.head()
# Out:
#         name   age  salary
# 0       bala  25.0  150000
# 1      kumar  26.0  175000
# 2  balakumar  27.0  200000
# 3       None   NaN  300000

# %%
data=[
    (1,'bala',25),
    (2,'kumar',26),
    (3,'balakumar',25)
]

columns=['id','name','age']

df=pd.DataFrame(data,columns=columns)
df.head()
# Out:
#    id       name  age
# 0   1       bala   25
# 1   2      kumar   26
# 2   3  balakumar   25

# %%
data=[
    {"name":"bala","age":10},
    {"name":"kumar","age":20},
    {"name":"balakumar","age":30},
]

df=pd.DataFrame(data)
df.head()
# Out:
#         name  age
# 0       bala   10
# 1      kumar   20
# 2  balakumar   30
