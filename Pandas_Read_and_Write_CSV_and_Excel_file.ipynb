# %% [markdown]
# <a href="https://colab.research.google.com/github/balakumar-dataengineer/testrepo/blob/master/Pandas_Read_and_Write_CSV_and_Excel_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/My Drive/Colab Notebooks/Pandas/demand_data_pandas1.csv')
df.head()
# Out:
#   Demand data     Unnamed: 1  Unnamed: 2 Unnamed: 3
# 0       Plant    Item number        Date     Demand
# 1         NaN         Item_A  04-03-2024        199
# 2         E80         Item_A  06-03-2024        112
# 3         E80  Not available  02-03-2024        158
# 4         E80         Item_A          Na        137

# %%
df=pd.read_csv('/content/drive/My Drive/Colab Notebooks/Pandas/demand_data_pandas1.csv',header=1)
df.head()
# Out:
#   Plant    Item number        Date Demand
# 0   NaN         Item_A  04-03-2024    199
# 1   E80         Item_A  06-03-2024    112
# 2   E80  Not available  02-03-2024    158
# 3   E80         Item_A          Na    137
# 4   E80         Item_B  05-03-2024     88

# %%
df=pd.read_csv('/content/drive/My Drive/Colab Notebooks/Pandas/demand_data_pandas1.csv',skiprows=1)
df.head()
# Out:
#   Plant    Item number        Date Demand
# 0   NaN         Item_A  04-03-2024    199
# 1   E80         Item_A  06-03-2024    112
# 2   E80  Not available  02-03-2024    158
# 3   E80         Item_A          Na    137
# 4   E80         Item_B  05-03-2024     88

# %%
df=pd.read_csv('/content/drive/My Drive/Colab Notebooks/Pandas/demand_data_pandas1.csv',header=None,skiprows=2)
df.head()
# Out:
#      0              1           2    3
# 0  NaN         Item_A  04-03-2024  199
# 1  E80         Item_A  06-03-2024  112
# 2  E80  Not available  02-03-2024  158
# 3  E80         Item_A          Na  137
# 4  E80         Item_B  05-03-2024   88

# %%
df=pd.read_csv('/content/drive/My Drive/Colab Notebooks/Pandas/demand_data_pandas1.csv',header=None,skiprows=2,names=['plant','item','demand_Date','demand_qty'])
df.head()
# Out:
#   plant           item demand_Date demand_qty
# 0   NaN         Item_A  04-03-2024        199
# 1   E80         Item_A  06-03-2024        112
# 2   E80  Not available  02-03-2024        158
# 3   E80         Item_A          Na        137
# 4   E80         Item_B  05-03-2024         88

# %%
df=pd.read_csv('/content/drive/My Drive/Colab Notebooks/Pandas/demand_data_pandas1.csv',header=1,nrows=2)
df.head()
# Out:
#   Plant Item number        Date  Demand
# 0   NaN      Item_A  04-03-2024     199
# 1   E80      Item_A  06-03-2024     112

# %%
df=pd.read_csv('/content/drive/My Drive/Colab Notebooks/Pandas/demand_data_pandas1.csv',header=1,na_values=['Not available','NaN','Na'])
df
# Out:
#   Plant Item number        Date  Demand
# 0   NaN      Item_A  04-03-2024   199.0
# 1   E80      Item_A  06-03-2024   112.0
# 2   E80         NaN  02-03-2024   158.0
# 3   E80      Item_A         NaN   137.0
# 4   E80      Item_B  05-03-2024    88.0
# 5   E80      Item_B  06-03-2024   149.0
# 6   E80         NaN  03-03-2024   176.0
# 7   E80      Item_C         NaN   169.0
# 8   E80      Item_C  02-03-2024     NaN

# %%
df=pd.read_csv('/content/drive/My Drive/Colab Notebooks/Pandas/demand_data_pandas1.csv',header=1,
               na_values={
                   "Demand":['Not available','Na'],
                   "Date":['Not available','Na']
               }
               )
df.Demand.dtype
# Out:
# dtype('float64')

# %%
df.to_csv('/content/drive/My Drive/Colab Notebooks/Pandas/data1.csv',index=False,columns=['Item number','Demand','Date'],header=False)

# %%
#Excel File read and write

df=pd.read_excel('/content/drive/My Drive/Colab Notebooks/Pandas/balakumar-31.xlsx','Sheet1',header=None,names=['id','status','time','rest','cost'],
                 skiprows=5,na_values={
                     "status":['Delivered1'],
                     "rest":['A2B - Adyar Ananda Bhavan']
                 })
df
# Out:
#                 id     status                time            rest  cost
# 0  155721000000000  Delivered 2023-10-08 13:17:31             NaN   191
# 1  155636000000000  Delivered 2023-10-07 13:47:25             NaN   256
# 2     173092000000  Delivered 2023-07-22 14:36:33             NaN   180
# 3     172593000000  Delivered 2023-07-16 20:07:57  Domino's Pizza   578
# 4     172572000000  Delivered 2023-07-16 14:11:50             NaN   361
# 5     170174000000  Delivered 2023-06-18 20:03:44        Anjappar   218

# %%
df.to_excel('/content/drive/My Drive/Colab Notebooks/Pandas/balakumar-34.xlsx',index=False,columns=['id','status','time','rest','cost'],
            startrow=5,startcol=8
            )

# %%
df1=pd.read_excel('/content/drive/My Drive/Colab Notebooks/Pandas/balakumar-31.xlsx','balakumar-2')
df2=pd.read_excel('/content/drive/My Drive/Colab Notebooks/Pandas/balakumar-31.xlsx','Sheet1')

with pd.ExcelWriter('/content/drive/My Drive/Colab Notebooks/Pandas/balakumar-35.xlsx') as writer:
  df1.to_excel(writer,sheet_name='bala')
  df2.to_excel(writer,sheet_name='kumar')

# %%
def convert_data(data):
  if data=='Delivered':
    return 'deliver'
  else:
    return data

df3=pd.read_excel('/content/drive/My Drive/Colab Notebooks/Pandas/balakumar-35.xlsx',converters={"orderStatus":convert_data})
df3
# Out:
#     Unnamed: 0          orderId orderStatus           orderTime  \
# 0            0  159373000000000     deliver 2023-11-19 19:40:53
# 1            1  159351000000000     deliver 2023-11-19 13:45:31
# 2            2  156328000000000     deliver 2023-10-15 13:51:36
# 3            3  155747000000000     deliver 2023-10-08 20:28:10
# 4            4  155721000000000     deliver 2023-10-08 13:17:31
# 5            5  155636000000000     deliver 2023-10-07 13:47:25
# 6            6     173092000000     deliver 2023-07-22 14:36:33
# 7            7     172593000000     deliver 2023-07-16 20:07:57
# 8            8     172572000000     deliver 2023-07-16 14:11:50
# 9            9     170174000000     deliver 2023-06-18 20:03:44
# 10          10     168943000000     deliver 2023-06-04 14:07:04
# 11          11     168862000000     deliver 2023-06-03 15:37:22
# 12          12     168339000000     deliver 2023-05-28 14:17:02
# 13          13     166009000000     deliver 2023-05-01 15:04:37
# ...
