# %% [markdown]
# <a href="https://colab.research.google.com/github/balakumar-dataengineer/testrepo/blob/master/Pandas_Handing_missing_data_fillna%2Cdropna%2Cinterpolate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df=pd.read_csv('/content/drive/My Drive/Colab Notebooks/Pandas/weather_data.csv')
print(type(df.Day[0]))
# Out:
# <class 'str'>

# %%
df=pd.read_csv('/content/drive/My Drive/Colab Notebooks/Pandas/weather_data.csv',parse_dates=['Day'],date_format='%d-%m-%Y')
type(df.Day[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.set_index('Day',inplace=True)
df
# Out:
#             Temperature  WindSpeed   Event
# Day
# 2025-01-01         33.0        NaN     NaN
# 2025-01-02         32.0        5.0   Sunny
# 2025-01-06          NaN        8.0    Rain
# 2025-01-07         28.0       10.0  Cloudy
# 2025-01-08         30.0        8.0   Sunny
# 2025-01-09         28.0        7.0     NaN
# 2025-01-10         32.0        5.0   Sunny
# 2025-01-11         33.0        NaN  Cloudy
# 2025-01-12         35.0       13.0  Cloudy
# 2025-01-13          NaN        NaN    Rain
# 2025-01-14         40.0       12.0    Rain

# %%
new_df=df.fillna(0)
new_df
# Out:
#             Temperature  WindSpeed   Event
# Day
# 2025-01-01         33.0        0.0       0
# 2025-01-02         32.0        5.0   Sunny
# 2025-01-06          0.0        8.0    Rain
# 2025-01-07         28.0       10.0  Cloudy
# 2025-01-08         30.0        8.0   Sunny
# 2025-01-09         28.0        7.0       0
# 2025-01-10         32.0        5.0   Sunny
# 2025-01-11         33.0        0.0  Cloudy
# 2025-01-12         35.0       13.0  Cloudy
# 2025-01-13          0.0        0.0    Rain
# 2025-01-14         40.0       12.0    Rain

# %%
new_df=df.fillna({
    "Temperature":32,
    "WindSpeed":12,
    "Event":'Rain'
})

new_df
# Out:
#             Temperature  WindSpeed   Event
# Day
# 2025-01-01         33.0       12.0    Rain
# 2025-01-02         32.0        5.0   Sunny
# 2025-01-06         32.0        8.0    Rain
# 2025-01-07         28.0       10.0  Cloudy
# 2025-01-08         30.0        8.0   Sunny
# 2025-01-09         28.0        7.0    Rain
# 2025-01-10         32.0        5.0   Sunny
# 2025-01-11         33.0       12.0  Cloudy
# 2025-01-12         35.0       13.0  Cloudy
# 2025-01-13         32.0       12.0    Rain
# 2025-01-14         40.0       12.0    Rain

# %%
df.fillna(method='bfill',limit=1)
# Out:
# <ipython-input-60-dd7a20a4949c>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill',limit=1)
#             Temperature  WindSpeed   Event
# Day
# 2025-01-01         33.0        5.0   Sunny
# 2025-01-02         32.0        5.0   Sunny
# 2025-01-06         28.0        8.0    Rain
# 2025-01-07         28.0       10.0  Cloudy
# 2025-01-08         30.0        8.0   Sunny
# 2025-01-09         28.0        7.0   Sunny
# 2025-01-10         32.0        5.0   Sunny
# 2025-01-11         33.0       13.0  Cloudy
# 2025-01-12         35.0       13.0  Cloudy
# 2025-01-13         40.0       12.0    Rain
# 2025-01-14         40.0       12.0    Rain

# %%
df.interpolate(method='time')
# Out:
# <ipython-input-63-b2b35dd0218a>:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='time')
#             Temperature  WindSpeed   Event
# Day
# 2025-01-01         33.0        NaN     NaN
# 2025-01-02         32.0        5.0   Sunny
# 2025-01-06         28.8        8.0    Rain
# 2025-01-07         28.0       10.0  Cloudy
# 2025-01-08         30.0        8.0   Sunny
# 2025-01-09         28.0        7.0     NaN
# 2025-01-10         32.0        5.0   Sunny
# 2025-01-11         33.0        9.0  Cloudy
# 2025-01-12         35.0       13.0  Cloudy
# 2025-01-13         37.5       12.5    Rain
# 2025-01-14         40.0       12.0    Rain

# %%
df.dropna(how='all')
# Out:
#             Temperature  WindSpeed   Event
# Day
# 2025-01-01         33.0        NaN     NaN
# 2025-01-02         32.0        5.0   Sunny
# 2025-01-06          NaN        8.0    Rain
# 2025-01-07         28.0       10.0  Cloudy
# 2025-01-08         30.0        8.0   Sunny
# 2025-01-09         28.0        7.0     NaN
# 2025-01-10         32.0        5.0   Sunny
# 2025-01-11         33.0        NaN  Cloudy
# 2025-01-12         35.0       13.0  Cloudy
# 2025-01-13          NaN        NaN    Rain
# 2025-01-14         40.0       12.0    Rain

# %%
df.dropna(thresh=2)
# Out:
#             Temperature  WindSpeed   Event
# Day
# 2025-01-02         32.0        5.0   Sunny
# 2025-01-07         28.0       10.0  Cloudy
# 2025-01-08         30.0        8.0   Sunny
# 2025-01-10         32.0        5.0   Sunny
# 2025-01-12         35.0       13.0  Cloudy
# 2025-01-14         40.0       12.0    Rain

# %%
dt=pd.date_range('01-01-2025','15-01-2025')
indx=pd.DatetimeIndex(dt)
df.reindex(indx)
df
# Out:
#             Temperature  WindSpeed   Event
# Day
# 2025-01-01         33.0        NaN     NaN
# 2025-01-02         32.0        5.0   Sunny
# 2025-01-06          NaN        8.0    Rain
# 2025-01-07         28.0       10.0  Cloudy
# 2025-01-08         30.0        8.0   Sunny
# 2025-01-09         28.0        7.0     NaN
# 2025-01-10         32.0        5.0   Sunny
# 2025-01-11         33.0        NaN  Cloudy
# 2025-01-12         35.0       13.0  Cloudy
# 2025-01-13          NaN        NaN    Rain
# 2025-01-14         40.0       12.0    Rain
