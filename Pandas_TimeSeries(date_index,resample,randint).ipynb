# %% [markdown]
# <a href="https://colab.research.google.com/github/balakumar-dataengineer/testrepo/blob/master/Pandas_TimeSeries(date_index%2Cresample%2Crandint).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df=pd.read_csv('/content/drive/My Drive/Colab Notebooks/Pandas/aapl.csv')
df
# Out:
#        Open    High     Low   Close    Volume
# 0    142.90  144.75  142.90  144.18  19201712
# 1    143.02  143.50  142.41  142.73  24128782
# 2    143.69  144.79  142.72  144.09  21569557
# 3    144.88  145.30  143.10  143.50  14277848
# 4    144.45  144.96  143.78  144.02  23024107
# ..      ...     ...     ...     ...       ...
# 246   98.92   99.30   98.50   98.78  30136990
# 247   97.39   98.99   97.32   98.79  38918997
# 248   97.41   97.67   96.84   96.87  25892171
# 249   97.17   97.70   97.12   97.42  24167463
# 250   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 5 columns]

# %%
rng=pd.date_range(start='2016-10-01',periods=251,freq='H')
rng
# Out:
# <ipython-input-37-25695be0df29>:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   rng=pd.date_range(start='2016-10-01',periods=251,freq='H')
# DatetimeIndex(['2016-10-01 00:00:00', '2016-10-01 01:00:00',
#                '2016-10-01 02:00:00', '2016-10-01 03:00:00',
#                '2016-10-01 04:00:00', '2016-10-01 05:00:00',
#                '2016-10-01 06:00:00', '2016-10-01 07:00:00',
#                '2016-10-01 08:00:00', '2016-10-01 09:00:00',
#                ...
#                '2016-10-11 01:00:00', '2016-10-11 02:00:00',
#                '2016-10-11 03:00:00', '2016-10-11 04:00:00',
#                '2016-10-11 05:00:00', '2016-10-11 06:00:00',
#                '2016-10-11 07:00:00', '2016-10-11 08:00:00',
#                '2016-10-11 09:00:00', '2016-10-11 10:00:00'],
#               dtype='datetime64[ns]', length=251, freq='h')

# %%
df.set_index(rng,inplace=True)
df.sort_index(inplace=True)

# %%
df.Close.mean()
# Out:
# np.float64(125.48749003984062)

# %%
df.resample('W').mean()
# Out:
#                Open     High      Low    Close      Volume
# 2016-10-09  143.788  144.660  142.982  143.704  20440401.2
# 2016-10-16  145.302  146.568  143.910  145.068  27895088.2
# 2016-10-23  145.120  146.176  144.106  145.024  29634923.0
# 2016-10-30  147.782  148.142  143.946  146.088  47010407.4
# 2016-11-06  154.418  155.446  153.802  154.838  24409549.6
# 2016-11-13  153.658  154.104  152.854  153.418  20429067.6
# 2016-11-20  153.478  154.194  152.530  153.346  24526693.0
# 2016-11-27  154.540  155.554  153.292  154.294  31321590.0
# 2016-12-04  149.962  151.728  149.432  151.150  32877613.0
# 2016-12-11  145.248  146.248  144.530  145.718  31951775.2
# 2016-12-18  143.108  143.810  142.688  143.312  19337513.0
# 2016-12-25  141.656  142.090  140.898  141.312  17356178.6
# 2017-01-01  143.756  144.278  142.698  143.164  22970371.8
# 2017-01-08  143.710  144.454  143.184  144.036  21987185.2
# 2017-01-15  140.580  142.036  139.992  141.532  25110385.6
# ...

# %%
# %matplotlib inline
df.Open.resample('QE').mean().plot(xlabel='Months',ylabel='price',kind='bar')
# Out:
# <Axes: xlabel='Months', ylabel='price'>

# %%
df.Open.asfreq('D').plot()
# Out:
# <Axes: >

# %%
df.asfreq('D',method='bfill').head(10)
# Out:
#               Open    High     Low   Close    Volume
# 2016-10-03  142.90  144.75  142.90  144.18  19201712
# 2016-10-04  143.02  143.50  142.41  142.73  24128782
# 2016-10-05  143.69  144.79  142.72  144.09  21569557
# 2016-10-06  144.88  145.30  143.10  143.50  14277848
# 2016-10-07  144.45  144.96  143.78  144.02  23024107
# 2016-10-08  144.71  145.13  142.28  143.68  31499368
# 2016-10-09  144.71  145.13  142.28  143.68  31499368
# 2016-10-10  144.71  145.13  142.28  143.68  31499368
# 2016-10-11  144.49  146.11  143.16  145.83  22082432
# 2016-10-12  145.01  146.16  143.62  143.73  24761891

# %%
import numpy as np
randval=np.random.randint(1,10,len(rng))

# %%
pd.Series(randval,index=rng)
# Out:
# 2016-10-01 00:00:00    6
# 2016-10-01 01:00:00    6
# 2016-10-01 02:00:00    3
# 2016-10-01 03:00:00    6
# 2016-10-01 04:00:00    4
#                       ..
# 2016-10-11 06:00:00    2
# 2016-10-11 07:00:00    3
# 2016-10-11 08:00:00    5
# 2016-10-11 09:00:00    9
# 2016-10-11 10:00:00    8
# Freq: h, Length: 251, dtype: int64
