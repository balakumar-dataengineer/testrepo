# %% [markdown]
# <a href="https://colab.research.google.com/github/balakumar-dataengineer/testrepo/blob/master/Pandas_groupby(split_apply_combine).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

df=pd.read_csv('/content/drive/My Drive/Colab Notebooks/Pandas/demand_data_pandas.csv')
df
# Out:
#   Plant           Item        Date         Demand
# 0   NaN         Item_A  04-03-2024            199
# 1   E80         Item_A  06-03-2024            112
# 2   E80  Not available  02-03-2024            158
# 3   E80         Item_A          Na            137
# 4   E80         Item_B  05-03-2024             88
# 5   E80         Item_B  06-03-2024            149
# 6   E80            NaN  03-03-2024            176
# 7   E80         Item_C         NaN            169
# 8   E80         Item_C  02-03-2024  Not available

# %%
new_df=df.replace({
 "Plant":{None:'E80'},
 "Item":{None:'Item_D',
         'Not available':'Item_D'},
 "Date":{None:'08-03-2024',
         "Na":"08-03-2024"},
 "Demand":{'Not available':10}
})

# %%
new_df['Demand']=pd.to_numeric(new_df['Demand'])
new_df.dtypes
g=new_df.groupby('Item')

# %%
for item,item_gdf in g:
  print(item)
  print(item_gdf)
# Out:
# Item_A
#   Plant    Item        Date  Demand
# 0   E80  Item_A  04-03-2024     199
# 1   E80  Item_A  06-03-2024     112
# 3   E80  Item_A  08-03-2024     137
# Item_B
#   Plant    Item        Date  Demand
# 4   E80  Item_B  05-03-2024      88
# 5   E80  Item_B  06-03-2024     149
# Item_C
#   Plant    Item        Date  Demand
# 7   E80  Item_C  08-03-2024     169
# 8   E80  Item_C  02-03-2024      10
# Item_D
#   Plant    Item        Date  Demand
# 2   E80  Item_D  02-03-2024     158
# 6   E80  Item_D  03-03-2024     176

# %%
g.get_group('Item_C')
# Out:
#   Plant    Item        Date  Demand
# 7   E80  Item_C  08-03-2024     169
# 8   E80  Item_C  02-03-2024      10

# %%
g.max()
# Out:
#        Plant        Date  Demand
# Item
# Item_A   E80  08-03-2024     199
# Item_B   E80  06-03-2024     149
# Item_C   E80  08-03-2024     169
# Item_D   E80  03-03-2024     176

# %%
g.min()
# Out:
#        Plant        Date  Demand
# Item
# Item_A   E80  04-03-2024     112
# Item_B   E80  05-03-2024      88
# Item_C   E80  02-03-2024      10
# Item_D   E80  02-03-2024     158

# %%
g.describe()
# Out:
#        Demand
#         count        mean         std    min     25%    50%     75%    max
# Item
# Item_A    3.0  149.333333   44.792112  112.0  124.50  137.0  168.00  199.0
# Item_B    2.0  118.500000   43.133514   88.0  103.25  118.5  133.75  149.0
# Item_C    2.0   89.500000  112.429978   10.0   49.75   89.5  129.25  169.0
# Item_D    2.0  167.000000   12.727922  158.0  162.50  167.0  171.50  176.0

# %%
g['Demand'].mean()
# Out:
# Item
# Item_A    149.333333
# Item_B    118.500000
# Item_C     89.500000
# Item_D    167.000000
# Name: Demand, dtype: float64
